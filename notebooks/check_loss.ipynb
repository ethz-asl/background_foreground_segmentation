# %%
from matplotlib import pyplot as plt
from bfseg.data.meshdist.dataLoader import DataLoader
import os
import tensorflow as tf

# %%
workingDir = "/home/rene/cla_dataset/cam0_preprocessed/"

# %%
unknown_class = 1

# %%
dLoader = DataLoader(workingDir, [480, 720], validationDir ='/home/rene/hiveLabels/')

# %%
ds_train, ds_valid = dLoader.getDataset()

# %%
data = tf.squeeze(tf.keras.backend.one_hot(label[0],3))

# %%
plt.imshow(data)

# %%
plt.imshow(data[...,2])

# %%
ignore = data[...,1]
plt.imshow(ignore)

# %%
plt.imshow(tf.cast(tf.math.logical_not(tf.cast(ignore, tf.bool)),tf.int32))

# %%
plt.imshow(tf.stack([data[...,0], data[...,2], data[...,0]], axis = ))

# %%
for img, label in ds_train.take(1):
    pass
plt.imshow(label[0])

# %%
plt.imshow(label[0] == unknown_class)

# %%
plt.imshow(img[0])
